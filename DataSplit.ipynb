# %%
import pandas as pd

# %%
data = pd.read_csv('food_atlas_combined.csv')
data.index=data.FIPS
data.drop('FIPS',axis=1,inplace=True)
data.head()
# Out:
#         PCH_LACCESS_POP_10_15  PCT_LACCESS_POP10  PCT_LACCESS_POP15  \
# FIPS
# 1001.0              -5.056026          33.769657          32.062255
# 1003.0             -13.204891          19.318473          16.767489
# 1005.0               6.067799          20.840972          22.105560
# 1007.0              -7.224696           4.559753           4.230324
# 1009.0             140.568857           2.700840           6.497380
#
#         PCH_LACCESS_LOWI_10_15  PCT_LACCESS_LOWI10  PCT_LACCESS_LOWI15  \
# FIPS
# 1001.0               22.439248            9.793530           11.991125
# 1003.0               -0.656270            5.460261            5.424427
# 1005.0               -5.959985           11.420316           10.739667
# 1007.0               21.307144            2.144661            2.601627
# 1009.0              171.081177            1.062468            2.880150
#
#         PCH_LACCESS_HHNV_10_15  PCT_LACCESS_HHNV10  PCT_LACCESS_HHNV15  \
# FIPS
# 1001.0                2.025888            3.284786            3.351332
# 1003.0              -11.300383            2.147827            1.905114
# 1005.0                4.678792            4.135869            4.329378
# 1007.0              -18.422377            3.458580            2.821427
# 1009.0                2.050367            3.269380            3.336414
#
#         PCT_LACCESS_SNAP15  ...  MEDHHINC15  POVRATE15  PERPOV10  \
# FIPS                        ...
# 1001.0            4.608749  ...     56580.0       12.7       0.0
# 1003.0            1.298900  ...     52387.0       12.9       0.0
# 1005.0            4.303147  ...     31433.0       32.0       1.0
# 1007.0            0.676710  ...     40767.0       22.2       0.0
# 1009.0            0.812727  ...     50487.0       14.7       0.0
#
#         CHILDPOVRATE15  PERCHLDPOV10  METRO13  POPLOSS10  State_dup.2  \
# FIPS
# 1001.0            18.8           0.0      1.0        0.0           AL
# 1003.0            19.6           0.0      1.0        0.0           AL
# 1005.0            45.2           1.0      0.0        0.0           AL
# 1007.0            29.3           1.0      1.0        0.0           AL
# 1009.0            22.2           0.0      1.0        0.0           AL
#
#         County_dup.2  PCT_OBESE_ADULTS17
# FIPS
# 1001.0       Autauga                36.3
# 1003.0       Baldwin                36.3
# 1005.0       Barbour                36.3
# 1007.0          Bibb                36.3
# 1009.0        Blount                36.3
#
# [5 rows x 147 columns]

# %%
# set a list of features for the model 
X = data.iloc[:,2:]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test = train_test_split(X)

# %%
X_train.to_csv("data_train.csv")

# %%
X_test.to_csv("data_test.csv")
